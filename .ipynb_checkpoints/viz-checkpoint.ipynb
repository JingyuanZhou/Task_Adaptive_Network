# %%
from model_debug import *
import torch
import torch.nn as nn
from win_dataset import *
from torch.utils.data import DataLoader
from tqdm import tqdm
from torchmetrics.functional import psnr, ssim, accuracy
import torch.nn.functional as F

import matplotlib.pyplot as plt
import seaborn as sns

# %%
model = GCANet()
model.load_state_dict(torch.load('/openbayes/home/snapshots_round2/model_30.pth'))
model = model.cuda()

# %%
class Args(object):
    def __init__(self):
        self.batch_size = 32
        self.num_workers = 0
        self.test_orig_images_path = '/openbayes/input/input1/clear/'
        self.test_degen_images_path = '/openbayes/input/input1/degen/'

# %%
def test(args, model, mode):
    model.eval()
    print('testing '+mode)
    weights_mean={}
    channel_weights_mean=np.zeros((14,1,120))
    with torch.no_grad():
        val_list = populate_test_list(args.test_orig_images_path, args.test_degen_images_path, mode)
        val_dataset = merge_dataset(val_list, train=False)
        val_dataloader = DataLoader(val_dataset, batch_size=1, num_workers=args.num_workers, shuffle=False, pin_memory=True)
        
        l = len(val_dataloader)
        for step, batch in enumerate(tqdm(val_dataloader)):
            data_orig, data_degen, label = [i.cuda() for i in batch]
            weights_dict,channel_weights = model(data_degen)
            
            channel_weights_mean+=channel_weights
            for key in weights_dict:
                if key in weights_mean.keys():
                    weights_mean[key]+=weights_dict[key]
                else:
                    weights_mean[key]=weights_dict[key]
        for key in weights_mean:
            weights_mean[key]=weights_mean[key]/l
        channel_weights_mean=channel_weights_mean/l
    return weights_mean,channel_weights_mean

# %%
args = Args()
hazy_o_weights,hazy_c_weights  = test(args,model,'hazy')
rain_o_weights,rain_c_weights = test(args,model,'rain')
raindrop_a_o_weights,raindrop_a_c_weights = test(args,model,'rain_drop_test_a')
raindrop_b_o_weights,raindrop_b_c_weights = test(args,model,'rain_drop_test_b')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# testing hazy
# Total testing examples: 500
# 100%|██████████| 500/500 [01:46<00:00,  4.68it/s]
#   0%|          | 0/1400 [00:00<?, ?it/s]
# testing rain
# Total testing examples: 1400
#  67%|██████▋   | 937/1400 [03:17<01:42,  4.52it/s]

# %%
# %matplotlib inline
plt.figure(figsize=(15,5))
hazy_ls=[]
for key in hazy_o_weights:
    length=hazy_o_weights[key].shape[1]
    for i in range(length):
        hazy_ls.append(hazy_o_weights[key][0,i,:].tolist())

plt.subplot(1,3,1)
sns.heatmap(hazy_ls)
plt.xlabel('operation_id',fontsize=20)
plt.ylabel('layer_id',fontsize=20)

rain_ls=[]
for key in rain_o_weights:
    length=rain_o_weights[key].shape[1]
    for i in range(length):
        rain_ls.append(rain_o_weights[key][0,i,:].tolist())

plt.subplot(1,3,2)
sns.heatmap(rain_ls)
plt.xlabel('operation_id',fontsize=20)
plt.ylabel('layer_id',fontsize=20)

raindrop_a_ls=[]
for key in raindrop_a_o_weights:
    length=raindrop_a_o_weights[key].shape[1]
    for i in range(length):
        raindrop_a_ls.append(raindrop_a_o_weights[key][0,i,:].tolist())

plt.subplot(1,3,3)
sns.heatmap(raindrop_a_ls)
plt.xlabel('operation_id',fontsize=20)
plt.ylabel('layer_id',fontsize=20)

plt.savefig('fig1.jpg')

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.heatmap(hazy_c_weights[:,0,:])
plt.xlabel('channel_id')
plt.ylabel('layer_id')
plt.subplot(1,3,2)
sns.heatmap(rain_c_weights[:,0,:])
plt.xlabel('channel_id')
plt.ylabel('layer_id')
plt.subplot(1,3,3)
sns.heatmap(raindrop_a_c_weights[:,0,:])
plt.xlabel('channel_id')
plt.ylabel('layer_id')
plt.savefig('fig2.jpg')

# %%
plt.subplots(4,1,figsize=(5,20))
for i,debuger in enumerate([hazy_debuger,rain_debuger,raindrop_a_debuger,raindrop_b_debuger]):
    res1_1_attns = torch.vstack([i.squeeze() for i in debuger.attns_dict['res1_1']])
    plt.subplot(4,1,i+1)
    sns.heatmap(res1_1_attns)

# %%
plt.subplots(4,1,figsize=(5,20))
for i,debuger in enumerate([hazy_debuger,rain_debuger,raindrop_a_debuger,raindrop_b_debuger]):
    res6_1_attns = torch.vstack([i.squeeze() for i in debuger.attns_dict['res6_1']])
    plt.subplot(4,1,i+1)
    sns.heatmap(res6_1_attns)

# %%
plt.subplots(4,1,figsize=(5,20))
for i,debuger in enumerate([hazy_debuger,rain_debuger,raindrop_a_debuger,raindrop_b_debuger]):
    res1_1_means = torch.vstack([i.squeeze() for i in debuger.INs_dict['mean']['res1_1']])
    plt.subplot(4,1,i+1)
    sns.heatmap(res1_1_means)

# %%
plt.subplots(4,1,figsize=(5,20))
for i,debuger in enumerate([hazy_debuger,rain_debuger,raindrop_a_debuger,raindrop_b_debuger]):
    res6_1_means = torch.vstack([i.squeeze() for i in debuger.INs_dict['mean']['res6_1']])
    plt.subplot(4,1,i+1)
    sns.heatmap(res6_1_means)

# %%
import pstats
p=pstats.Stats('result.out')
p.print_stats()
p.sort_stats('calls').print_stats()
p.sort_stats('cumulative').print_stats()
# Out:
# Tue Jun  1 16:02:00 2021    result.out
#
#          3180283 function calls (3113867 primitive calls) in 88.821 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         9    0.002    0.000    0.002    0.000 {method 'readlines' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'send' of 'generator' objects}
#        57    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method maketrans}
#         1    0.000    0.000    0.000    0.000 {method 'rfind' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'bytes' objects}
#         9    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#      1942    0.001    0.000    0.001    0.000 {method 'find' of 'bytearray' objects}
#        86    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getdefaultencoding}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getdlopenflags}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#       379    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#      1323    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.setdlopenflags}
#    135923    0.371    0.000    0.371    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      3531    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'collections.OrderedDict' objects}
#       489    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'keys' of 'mappingproxy' objects}
#      1765    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       171    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#        17    0.000    0.000    0.000    0.000 {method 'copy' of 'mappingproxy' objects}
#        72    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         3    0.000    0.000    0.000    0.000 {method 'deleter' of 'property' objects}
#        68    0.002    0.000    0.002    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#         5    0.003    0.001    0.003    0.001 {method 'read' of '_io.TextIOWrapper' objects}
#        77    0.000    0.000    0.000    0.000 {method 'flush' of '_io.TextIOWrapper' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#        25    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#        13    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         9    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#      1431    0.020    0.000    0.020    0.000 {method 'read' of '_io.FileIO' objects}
#        40    0.001    0.000    0.001    0.000 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         4    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#       255    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {built-in method time.localtime}
#        74    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#      1164    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         2    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISREG}
#        31    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISLNK}
#         8    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#       103    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#         7    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        64    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        81    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#       817    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#         3    0.000    0.000    0.000    0.000 {built-in method _operator.lt}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.ge}
#         2    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#        27    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#        77    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#     28227    0.014    0.000    0.014    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#      2121    0.003    0.000    0.003    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#      1369    0.016    0.000    0.016    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#       479    0.009    0.000    0.009    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
#      1532    0.003    0.000    0.003    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'finditer' of '_sre.SRE_Pattern' objects}
#      8940    0.001    0.000    0.001    0.000 {method 'group' of '_sre.SRE_Match' objects}
#        37    0.000    0.000    0.000    0.000 {method 'end' of '_sre.SRE_Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'groups' of '_sre.SRE_Match' objects}
#        12    0.000    0.000    0.000    0.000 {method 'groupdict' of '_sre.SRE_Match' objects}
#       178    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#      1522    0.000    0.000    0.000    0.000 {built-in method _sre.getlower}
#      9062    0.043    0.000    0.043    0.000 {built-in method posix.stat}
#       308    0.001    0.000    0.001    0.000 {built-in method posix.getcwd}
#       605    0.015    0.000    0.015    0.000 {built-in method posix.listdir}
#        32    0.000    0.000    0.000    0.000 {built-in method posix.lstat}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.uname}
#         6    0.236    0.039    0.236    0.039 {built-in method posix.fork}
#        93    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        22    0.035    0.002    0.035    0.002 {built-in method posix.waitpid}
#        22    0.001    0.000    0.001    0.000 {built-in method posix.close}
#         1    0.006    0.006    0.006    0.006 {built-in method posix.read}
#        15    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.putenv}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.unsetenv}
#         7    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         7    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#         7    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.sysconf}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.cpu_count}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.scandir}
#     37575    0.006    0.000    0.006    0.000 {built-in method posix.fspath}
#       274    0.541    0.002    0.541    0.002 {method 'acquire' of '_thread.lock' objects}
#        95    0.001    0.000    0.001    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#       165    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       165    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        88    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        88    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         9    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#      3442    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#      6933    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread._set_sentinel}
#      1431    0.268    0.000    0.268    0.000 {built-in method marshal.loads}
#     10424    0.002    0.000    0.002    0.000 {built-in method _imp.acquire_lock}
#     10424    0.002    0.000    0.002    0.000 {built-in method _imp.release_lock}
#         5    0.000    0.000    0.000    0.000 {built-in method _imp.create_builtin}
#       159    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#      1677    0.001    0.000    0.001    0.000 {built-in method _imp.is_frozen}
#   206/204    0.439    0.002    0.527    0.003 {built-in method _imp.create_dynamic}
#   206/167    0.164    0.001    0.201    0.001 {built-in method _imp.exec_dynamic}
#         5    0.000    0.000    0.000    0.000 {built-in method _imp.exec_builtin}
#      1431    0.001    0.000    0.001    0.000 {built-in method _imp._fix_co_filename}
# 3337/3265    0.064    0.000    0.208    0.000 {built-in method builtins.__build_class__}
#    632/62    0.001    0.000    1.546    0.025 {built-in method builtins.__import__}
#       207    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       873    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#      7876    0.097    0.000    0.117    0.000 {built-in method builtins.any}
#      2481    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       994    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#       430    0.022    0.000    0.022    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#        31    0.001    0.000    0.001    0.000 {built-in method builtins.dir}
#       368    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.eval}
#    2031/1    0.060    0.000   88.824   88.824 {built-in method builtins.exec}
#     42358    0.018    0.000    0.019    0.000 {built-in method builtins.getattr}
#      1598    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#    184912    0.326    0.000    0.328    0.000 {built-in method builtins.hasattr}
# 1456/1381    0.000    0.000    0.001    0.000 {built-in method builtins.hash}
#     34973    0.008    0.000    0.008    0.000 {built-in method builtins.id}
# 145909/145906    0.026    0.000    0.030    0.000 {built-in method builtins.isinstance}
# 7237/5370    0.002    0.000    0.010    0.000 {built-in method builtins.issubclass}
#      3282    0.003    0.000    0.003    0.000 {built-in method builtins.iter}
# 169853/167516    0.031    0.000    0.033    0.000 {built-in method builtins.len}
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#       645    0.003    0.000    0.005    0.000 {built-in method builtins.max}
#     18063    0.004    0.000    0.004    0.000 {built-in method builtins.min}
#       337    0.000    0.000    0.015    0.000 {built-in method builtins.next}
#      4194    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#       126    0.004    0.000    0.004    0.000 {built-in method builtins.pow}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       205    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#     10297    0.003    0.000    0.004    0.000 {built-in method builtins.setattr}
#        48    0.003    0.000    0.052    0.001 {built-in method builtins.sorted}
#       196    0.003    0.000    0.014    0.000 {built-in method builtins.sum}
#        52    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#        63    0.001    0.000    0.001    0.000 {built-in method _warnings.warn}
#        43    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#        55    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#      6745    0.004    0.000    0.004    0.000 {method 'replace' of 'str' objects}
#     57297    0.028    0.000    0.028    0.000 {method 'split' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
# 27169/27164    0.009    0.000    0.012    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'title' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#      8074    0.006    0.000    0.006    0.000 {method 'expandtabs' of 'str' objects}
#        52    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        72    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#      7701    0.002    0.000    0.002    0.000 {method 'lower' of 'str' objects}
#     19534    0.002    0.000    0.002    0.000 {method 'lstrip' of 'str' objects}
#      2695    0.001    0.000    0.001    0.000 {method 'rfind' of 'str' objects}
#     34930    0.006    0.000    0.006    0.000 {method 'rstrip' of 'str' objects}
#     14210    0.004    0.000    0.004    0.000 {method 'rpartition' of 'str' objects}
#      8127    0.010    0.000    0.010    0.000 {method 'splitlines' of 'str' objects}
#      1602    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        54    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#       145    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#     70414    0.010    0.000    0.010    0.000 {method 'startswith' of 'str' objects}
#     38190    0.006    0.000    0.006    0.000 {method 'endswith' of 'str' objects}
#      1299    0.000    0.000    0.000    0.000 {method 'isupper' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'isalnum' of 'str' objects}
#      1828    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#       880    0.000    0.000    0.000    0.000 {method 'zfill' of 'str' objects}
#      5806    0.007    0.000    0.008    0.000 {method 'format' of 'str' objects}
#        46    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#       425    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#       471    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        90    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#      4289    0.022    0.000    0.022    0.000 {built-in method __new__ of type object at 0x56262f2eae00}
#         1    0.000    0.000    0.000    0.000 {method 'indices' of 'slice' objects}
#      4623    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#       186    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#       397    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#        10    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#       606    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#       136    0.001    0.000    0.001    0.000 {method 'issuperset' of 'frozenset' objects}
#        10    0.000    0.000    0.000    0.000 {method 'tolist' of 'memoryview' objects}
#        10    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#     56195    0.009    0.000    0.009    0.000 {method 'get' of 'dict' objects}
#       970    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       120    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        36    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      1352    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        25    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#      2612    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#        98    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       172    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       312    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#      2883    0.002    0.000    0.002    0.000 {built-in method from_bytes}
#    162237    0.015    0.000    0.015    0.000 {method 'append' of 'list' objects}
#        64    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       996    0.002    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#        74    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        22    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        37    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        31    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _signal.signal}
#         1    0.000    0.000    0.000    0.000 {built-in method _signal.getsignal}
#         1    0.005    0.005    0.016    0.016 {built-in method torch._C._initExtension}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._autograd_init}
#       658    0.000    0.000    0.000    0.000 {built-in method torch._C._add_docstr}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._init_names}
#      8000    0.004    0.000    0.004    0.000 {built-in method torch._C._get_cudnn_enabled}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._set_worker_pids}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._remove_worker_pids}
#         4    0.000    0.000    0.000    0.000 {built-in method torch._C._error_if_any_worker_fails}
#      2334    0.000    0.000    0.000    0.000 {built-in method torch._C.set_grad_enabled}
#      2334    0.001    0.000    0.001    0.000 {built-in method torch._C.is_grad_enabled}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._multiprocessing_init}
#         1    0.005    0.005    0.005    0.005 {built-in method torch._C._cuda_init}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_getDevice}
#        12    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_getDeviceCount}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_getArchFlags}
#         2    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_isInBadFork}
#         8    0.052    0.006    0.052    0.006 {built-in method torch._C._cuda_isDriverSufficient}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_getCompiledVersion}
#         1    0.001    0.001    0.001    0.001 {built-in method torch._C._c10d_init}
#         1    0.001    0.001    0.001    0.001 {built-in method torch._C._rpc_init}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._dist_autograd_init}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._jit_init}
#      3456    1.211    0.000    1.211    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#      1613   19.303    0.012   19.360    0.012 {method 'cuda' of 'torch._C._TensorBase' objects}
#     11743    0.008    0.000    0.008    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#       252    0.004    0.000    0.004    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#       378    0.005    0.000    0.005    0.000 {method 'int' of 'torch._C._TensorBase' objects}
#       442    0.046    0.000    0.046    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#       630    0.001    0.000    0.001    0.000 {method 'long' of 'torch._C._TensorBase' objects}
#        64    0.001    0.000    0.001    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#       313    0.000    0.000    0.000    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#     17515    0.117    0.000    0.117    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#        64    0.084    0.001    0.084    0.001 {method 'to' of 'torch._C._TensorBase' objects}
#         1    0.002    0.002    0.002    0.002 {method 'tolist' of 'torch._C._TensorBase' objects}
#       126    0.002    0.000    0.002    0.000 {method 'type' of 'torch._C._TensorBase' objects}
#     63378    1.041    0.000    1.041    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#     31689    0.478    0.000    0.478    0.000 {method 'addcdiv_' of 'torch._C._TensorBase' objects}
#     31689    0.655    0.000    0.655    0.000 {method 'addcmul_' of 'torch._C._TensorBase' objects}
#       252    0.006    0.000    0.006    0.000 {method 'all' of 'torch._C._TensorBase' objects}
#       958    0.140    0.000    0.140    0.000 {method 'clone' of 'torch._C._TensorBase' objects}
#      1021    0.006    0.000    0.006    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#     31186    0.044    0.000    0.044    0.000 {method 'detach_' of 'torch._C._TensorBase' objects}
#      3519    0.323    0.000    0.323    0.000 {method 'expand' of 'torch._C._TensorBase' objects}
#       126    0.001    0.000    0.001    0.000 {method 'expand_as' of 'torch._C._TensorBase' objects}
#       339    0.002    0.000    0.002    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#      1134    0.001    0.000    0.001    0.000 {method 'is_floating_point' of 'torch._C._TensorBase' objects}
#       126    0.004    0.000    0.004    0.000 {method 'log_softmax' of 'torch._C._TensorBase' objects}
#       693    0.021    0.000    0.021    0.000 {method 'max' of 'torch._C._TensorBase' objects}
#       189    0.006    0.000    0.006    0.000 {method 'mean' of 'torch._C._TensorBase' objects}
#       693    0.019    0.000    0.019    0.000 {method 'min' of 'torch._C._TensorBase' objects}
#     95067    1.606    0.000    1.606    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#        52    0.001    0.000    0.001    0.000 {method 'normal_' of 'torch._C._TensorBase' objects}
#       252    0.010    0.000    0.010    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C._TensorBase' objects}
#        63    0.002    0.000    0.002    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'repeat' of 'torch._C._TensorBase' objects}
#       316    0.002    0.000    0.002    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#       126    0.007    0.000    0.007    0.000 {method 'scatter' of 'torch._C._TensorBase' objects}
#       126    0.002    0.000    0.002    0.000 {method 'scatter_' of 'torch._C._TensorBase' objects}
#       128    0.004    0.000    0.004    0.000 {method 'softmax' of 'torch._C._TensorBase' objects}
#     31689    0.589    0.000    0.589    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#      1260    0.009    0.000    0.009    0.000 {method 'squeeze' of 'torch._C._TensorBase' objects}
#      1261    0.035    0.000    0.035    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#      1977    0.116    0.000    0.116    0.000 {method 't' of 'torch._C._TensorBase' objects}
#       126    0.006    0.000    0.006    0.000 {method 'topk' of 'torch._C._TensorBase' objects}
#      1398    0.182    0.000    0.182    0.000 {method 'transpose' of 'torch._C._TensorBase' objects}
#       199    0.010    0.000    0.010    0.000 {method 'uniform_' of 'torch._C._TensorBase' objects}
#      2231    0.119    0.000    0.119    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#      3318    0.312    0.000    0.312    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#     31411    1.269    0.000    1.269    0.000 {method 'zero_' of 'torch._C._TensorBase' objects}
#       503    0.001    0.000    0.001    0.000 {built-in method _make_subclass}
#         3    0.010    0.003    0.010    0.003 {built-in method torch._C._jit_get_operation}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._tracer_warn_use_python}
#     34158    0.399    0.000    0.399    0.000 {built-in method torch._C._get_tracing_state}
#       529    0.001    0.000    0.001    0.000 {built-in method torch._C._log_api_usage_once}
#         3    0.000    0.000    0.000    0.000 {built-in method torch._ops.torchvision._cuda_version}
#         3    0.000    0.000    0.000    0.000 {built-in method torch.cuda._get_device_properties}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:347(DoubleStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:351(FloatStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:355(HalfStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:359(LongStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:363(IntStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:367(ShortStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:371(CharStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:375(ByteStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:379(BoolStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:383(BFloat16Storage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:386(ComplexDoubleStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:389(ComplexFloatStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:392(QUInt8Storage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:395(QInt8Storage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:398(QInt32Storage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:416(manager_path)
#         1    0.001    0.001    0.523    0.523 /usr/local/lib/python3.6/site-packages/torch/__init__.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_utils.py:367(KeyErrorMessage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_utils.py:373(ExceptionWrapper)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_utils.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_utils_internal.py:17(get_file_path)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_utils_internal.py:29(prepare_multiprocessing_environment)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_utils_internal.py:33(resolve_library_path)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_utils_internal.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/version.py:1(<module>)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_six.py:46(__new__)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_six.py:44(metaclass)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_six.py:39(with_metaclass)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_six.py:21(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:13(Empty)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:17(Full)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:27(__init__)
#        64    0.001    0.000    0.537    0.008 /usr/local/lib/python3.6/queue.py:147(get)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:199(_init)
#        68    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:202(_qsize)
#        64    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:210(_get)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:21(Queue)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:214(PriorityQueue)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:233(LifoQueue)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/queue.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/random.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/serialization.py:30(SourceChangeWarning)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/_quickshift.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/boundaries.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/_clear_border.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/_join.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/skimage/segmentation/_watershed.py:25(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/_chan_vese.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/morphsnakes.py:20(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/morphsnakes.py:18(_fcycle)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/morphsnakes.py:34(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/morphsnakes.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:26(FastSnowyLandscape)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:197(CloudLayer)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:500(Clouds)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:604(Fog)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:683(SnowflakesLayer)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:1032(Snowflakes)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:1225(RainLayer)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:1342(Rain)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/weather.py:15(<module>)
#         3    0.003    0.001    1.882    0.627 /usr/local/lib/python3.6/glob.py:9(glob)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/glob.py:22(iglob)
#     27454    0.012    0.000    1.879    0.000 /usr/local/lib/python3.6/glob.py:39(_iglob)
#     27454    0.010    0.000    0.016    0.000 /usr/local/lib/python3.6/glob.py:82(<genexpr>)
#         3    0.006    0.002    1.809    0.603 /usr/local/lib/python3.6/glob.py:79(_glob1)
#     27454    1.747    0.000    1.747    0.000 /usr/local/lib/python3.6/glob.py:114(_iterdir)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/glob.py:145(has_magic)
#     27454    0.006    0.000    0.006    0.000 /usr/local/lib/python3.6/glob.py:152(_ishidden)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/glob.py:1(<module>)
#         1    0.000    0.000    0.017    0.017 /usr/local/lib/python3.6/site-packages/torch/__init__.py:133(_load_global_deps)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/__init__.py:196(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/rank/_percentile.py:23(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/rank/bilateral.py:24(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/_median.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/_unsharp_mask.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/_window.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/segmentation/_felzenszwalb.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 /usr/local/lib/python3.6/site-packages/skimage/segmentation/slic_superpixels.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/scipy/cluster/vq.py:83(ClusterError)
#         1    0.000    0.000    0.003    0.003 /usr/local/lib/python3.6/site-packages/scipy/cluster/__init__.py:22(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/scipy/cluster/vq.py:66(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/scipy/cluster/hierarchy.py:150(ClusterWarning)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/scipy/cluster/hierarchy.py:1111(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/scipy/cluster/hierarchy.py:1080(ClusterNode)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/scipy/cluster/hierarchy.py:85(<module>)
#         1    0.000    0.000    0.005    0.005 /usr/local/lib/python3.6/site-packages/skimage/feature/_orb_descriptor_positions.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/gzip.py:69(_PaddedFile)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/gzip.py:110(GzipFile)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/gzip.py:377(_GzipReader)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/gzip.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/match.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/blob.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/haar.py:2(<module>)
#         1    0.000    0.000    0.003    0.003 /usr/local/lib/python3.6/site-packages/skimage/filters/rank/__init__.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/skimage/filters/rank/generic.py:49(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/misc.py:16(<dictcomp>)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/misc.py:19(default_selem)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/misc.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/selem.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/grey.py:84(pad_for_eccentric_selems)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/grey.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/skimage/morphology/_skeletonize.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/convex_hull.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/greyreconstruct.py:11(<module>)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/skimage/morphology/extrema.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/_util.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/_flood_fill.py:5(<module>)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/skimage/morphology/max_tree.py:38(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/_deprecated.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/orb.py:22(ORB)
#         1    0.000    0.000    0.006    0.006 /usr/local/lib/python3.6/site-packages/skimage/feature/orb.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/_daisy.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/_hog.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/texture.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/peak.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/skimage/feature/corner.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/util.py:7(FeatureDetector)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/util.py:24(DescriptorExtractor)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/util.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/template.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/brief.py:11(BRIEF)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/brief.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/censure.py:111(CENSURE)
#         1    0.000    0.000    0.006    0.006 /usr/local/lib/python3.6/site-packages/skimage/feature/censure.py:1(<module>)
#         1    0.000    0.000    0.006    0.006 /usr/local/lib/python3.6/site-packages/skimage/morphology/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/binary.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/morphology/misc.py:11(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/thresholding.py:1(<module>)
#         1    0.000    0.000    0.022    0.022 /usr/local/lib/python3.6/site-packages/skimage/filters/ridges.py:9(<module>)
#         1    0.000    0.000    0.021    0.021 /usr/local/lib/python3.6/site-packages/skimage/feature/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/feature/_canny.py:13(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/__init__.py:17(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:104(ParseError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:123(Element)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:494(QName)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:542(ElementTree)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:1138(_ListDataStream)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:1248(XMLPullParser)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:1360(TreeBuilder)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementTree.py:1435(XMLParser)
#         1    0.000    0.000    0.002    0.002 /usr/local/lib/python3.6/xml/etree/ElementTree.py:34(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/xml/etree/ElementPath.py:246(_SelectorContext)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/xml/etree/ElementPath.py:59(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_dwt.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_c99_config.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_utils.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_multidim.py:8(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_thresholding.py:9(<module>)
#         1    0.001    0.001    0.001    0.001 /usr/local/lib/python3.6/site-packages/pywt/_wavelet_packets.py:27(BaseNode)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_wavelet_packets.py:395(Node)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_wavelet_packets.py:453(Node2D)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_wavelet_packets.py:534(WaveletPacket)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_wavelet_packets.py:634(WaveletPacket2D)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/pywt/_wavelet_packets.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_swt.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_cwt.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/data/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/data/_readers.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/version.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/data/_wavelab_signals.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_pytesttester.py:70(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_pytesttester.py:45(PytestTester)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_pytesttester.py:26(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/restoration/_cycle_spin.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/restoration/non_local_means.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/restoration/inpaint.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/restoration/j_invariant.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/_rank_order.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/skimage/filters/_gabor.py:1(<module>)
#         1    0.000    0.000    0.007    0.007 /usr/local/lib/python3.6/site-packages/skimage/restoration/_denoise.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/__init__.py:28(<listcomp>)
#         1    0.000    0.000    0.007    0.007 /usr/local/lib/python3.6/site-packages/pywt/__init__.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_extensions/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_functions.py:8(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/pywt/_multilevel.py:1194(FswavedecnResult)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.6/site-packages/pywt/_multilevel.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:70(Superpixels)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:448(Voronoi)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:662(UniformVoronoi)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:785(RegularGridVoronoi)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:952(RelativeRegularGridVoronoi)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:1134(IPointsSampler)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:1193(RegularGridPointsSampler)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:1322(RelativeRegularGridPointsSampler)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/imgaug/augmenters/segmentation.py:1420(DropoutPointsSampler)
# ...
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/quantization/inception.py:122(QuantizableInceptionC)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/quantization/inception.py:132(QuantizableInceptionD)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/quantization/inception.py:175(QuantizableInceptionAux)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/ops/misc.py:23(ConvTranspose2d)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/onnx/symbolic_opset9.py:274(_reduce_op_symbolic)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/onnx/symbolic_opset9.py:910(decorator)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/onnx/symbolic_opset9.py:919(wrap_logical_op_with_negation)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/segmentation/deeplabv3.py:40(ASPPConv)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/segmentation/deeplabv3.py:50(ASPPPooling)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/segmentation/deeplabv3.py:65(ASPP)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/segmentation/fcn.py:9(FCN)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/ops/poolers.py:41(LevelMapper)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/ops/feature_pyramid_network.py:143(ExtraFPNBlock)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/inception.py:354(InceptionE)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/googlenet.py:256(InceptionAux)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/googlenet.py:285(BasicConv2d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/mobilenet.py:33(ConvBNReLU)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/mobilenet.py:45(InvertedResidual)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torchvision/models/mnasnet.py:23(_InvertedResidual)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py:18(_IterableDatasetFetcher)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py:38(_MapDatasetFetcher)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/utils/data/dataset.py:8(Dataset)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/utils/data/dataloader.py:392(_SingleProcessDataLoaderIter)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/utils/data/_utils/worker.py:47(ManagerWatchdog)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/backends/quantized/__init__.py:26(_QEngineProp)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/backends/quantized/__init__.py:33(_SupportedQEnginesProp)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/distributions/constraints.py:83(_DependentProperty)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/distributions/constraints.py:142(_IntegerGreaterThan)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/distributions/constraints.py:170(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/distributions/constraints.py:182(_GreaterThanEq)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/distributions/constraints.py:235(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/distributions/constraints.py:278(_PositiveDefinite)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/unix_events.py:687(_UnixSubprocessTransport)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/protocols.py:62(Protocol)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/queues.py:14(QueueEmpty)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/transports.py:155(DatagramTransport)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/events.py:216(AbstractServer)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/events.py:584(_Local)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/events.py:631(_RunningLoop)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/base_futures.py:13(InvalidStateError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/concurrent/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/concurrent/futures/process.py:102(_ExceptionWithTraceback)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/concurrent/futures/process.py:115(_WorkItem)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/concurrent/futures/process.py:372(BrokenProcessPool)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/coroutines.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/coroutines.py:61(__iter__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/asyncio/coroutines.py:63(__next__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/tqdm/std.py:38(TqdmKeyError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/tqdm/std.py:59(TqdmDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/tqdm/std.py:100(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/urllib/response.py:57(addinfo)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/tqdm/_monitor.py:9(TqdmSynchronisationWarning)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/urllib/error.py:73(ContentTooShortError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/ipaddress.py:19(AddressValueError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/ipaddress.py:23(NetmaskValueError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/uu.py:39(Error)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/ssl.py:221(CertificateError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/calendar.py:31(IllegalWeekdayError)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/calendar.py:55(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/calendar.py:141(setfirstweekday)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/calendar.py:532(LocaleHTMLCalendar)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/http/client.py:1459(HTTPException)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/http/client.py:1475(UnknownTransferEncoding)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/http/client.py:1478(UnimplementedFileMode)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/http/client.py:1499(CannotSendRequest)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/http/client.py:1515(LineTooLong)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/http/client.py:1520(RemoteDisconnected)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/parser.py:71(HeaderParser)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:12(MessageParseError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:16(HeaderParseError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:41(NoBoundaryInMultipartDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:44(StartBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:47(CloseBoundaryNotFoundDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:50(FirstHeaderLineIsContinuationDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:56(MissingHeaderBodySeparatorDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:61(MultipartInvariantViolationDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:64(InvalidMultipartContentTransferEncodingDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:67(UndecodableBytesDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:104(ObsoleteHeaderDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/email/errors.py:107(NonASCIILocalPartDefect)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:409(ExponentialLR)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:438(CosineAnnealingLR)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/multiprocessing/spawn.py:122(SpawnContext)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/optim/optimizer.py:9(_RequiredParameter)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/intrinsic/modules/fused.py:41(ConvBn1d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/intrinsic/modules/fused.py:59(ConvBnReLU1d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/intrinsic/modules/fused.py:68(ConvBnReLU2d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/modules/batchnorm.py:210(BatchNorm2d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/modules/batchnorm.py:281(BatchNorm3d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/modules/dropout.py:103(Dropout3d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/modules/padding.py:407(ZeroPad2d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/modules/conv.py:1084(_ConvTransposeMixin)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/modules/activation.py:302(Hardsigmoid)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/nn/modules/activation.py:546(GELU)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/autograd/profiler.py:634(Interval)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/autograd/profiler.py:957(EnforceUnique)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/typing_extensions.py:407(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/typing_extensions.py:584(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/typing_extensions.py:1172(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/typing_extensions.py:1197(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/typing_extensions.py:1673(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/typing_extensions.py:1993(Annotated)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/autograd/function.py:260(_nested_map)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/autograd/grad_mode.py:73(enable_grad)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/distributed/rpc/api.py:369(RRefMeta)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/_jit_internal.py:700(BroadcastingListCls)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/sparse.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:144(DeferredCudaCallError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:498(FloatStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:506(IntStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:514(CharStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:518(ByteStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:526(BoolStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:530(BFloat16Storage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/cuda/__init__.py:533(ComplexDoubleStorage)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/serialization.py:197(_opener)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/torch/serialization.py:239(_open_zipfile_reader)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/tarfile.py:275(TarError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/tarfile.py:281(ReadError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/tarfile.py:290(HeaderError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/tarfile.py:296(TruncatedHeaderError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/tarfile.py:299(EOFHeaderError)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/tarfile.py:305(SubsequentHeaderError)
#         2    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath._set_madvise_hugepage}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/random.py:690(seed)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/site-packages/albumentations/core/__init__.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.6/contextlib.py:36(_recreate_cm)
